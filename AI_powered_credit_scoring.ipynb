# %% [markdown]
# <a href="https://colab.research.google.com/github/somyajain28/AI-powered-credit-scoring/blob/main/AI_powered_credit_scoring.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas numpy scikit-learn xgboost shap matplotlib streamlit joblib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 45.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 95.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 7.0.0
#     Uninstalling cachetools-7.0.0:
#       Successfully uninstalled cachetools-7.0.0
# ...
